# %% [markdown]
# # Look up survey question and answer concept IDs in All of Us
#
# This notebook shows how to:
#
# 1. Search for **survey questions** in `ds_survey` by survey name and keyword.
# 2. Retrieve all **answer options** (`answer_concept_id` and answer text) for a chosen question.
#
# We will use the curated dataset specified by the `WORKSPACE_CDR` environment variable.

# %%
import os
import pandas as pd

# Get the BigQuery curated dataset for the current workspace context.
CDR = os.environ["WORKSPACE_CDR"]
USE_BQSTORAGE = "BIGQUERY_STORAGE_API_ENABLED" in os.environ

# Make long question/answer text fully visible in outputs.
pd.set_option("display.max_colwidth", None)

print(f"Using CDR dataset: {CDR}")
# Out:
# Using CDR dataset: fc-aou-cdr-prod-ct.C2022Q4R13

# %%
# ---------------------------------------------------------------
#  Search RA-related questions and answers in ds_survey
# ---------------------------------------------------------------

survey_name = "Personal and Family Health History"
keyword = "rheumatoid arthritis (ra)"  # case-insensitive search

query = f"""
SELECT DISTINCT
  question_concept_id,
  question,
  answer_concept_id,
  answer,
  survey
FROM `{CDR}.ds_survey`
WHERE survey = '{survey_name}'
  AND LOWER(question) LIKE '%{keyword.lower()}%'
ORDER BY question_concept_id, answer_concept_id
"""

df_q = pd.read_gbq(
    query,
    dialect="standard",
    use_bqstorage_api=USE_BQSTORAGE,
)

print(f"Found {df_q['question_concept_id'].nunique()} question(s) and {len(df_q)} question–answer pair(s).")
df_q.head()
# Out:
# Found 4 question(s) and 20 question–answer pair(s).
#    question_concept_id  \
# 0               836820
# 1               836820
# 2               836820
# 3               836820
# 4               836820
#
#                                                                                            question  \
# 0  Including yourself, who in your family has had rheumatoid arthritis (RA)? Select all that apply.
# 1  Including yourself, who in your family has had rheumatoid arthritis (RA)? Select all that apply.
# 2  Including yourself, who in your family has had rheumatoid arthritis (RA)? Select all that apply.
# 3  Including yourself, who in your family has had rheumatoid arthritis (RA)? Select all that apply.
# 4  Including yourself, who in your family has had rheumatoid arthritis (RA)? Select all that apply.
#
#    answer_concept_id  \
# 0             903096
# 1            1384653
# 2           43529773
# 3           43529774
# 4           43529775
#
#                                                                                     answer  \
# 0                                                                                PMI: Skip
# 1         Including yourself, who in your family has had rheumatoid arthritis (RA)? - Self
# 2     Including yourself, who in your family has had rheumatoid arthritis (RA)? - Daughter
# 3       Including yourself, who in your family has had rheumatoid arthritis (RA)? - Father
# 4  Including yourself, who in your family has had rheumatoid arthritis (RA)? - Grandparent
#
#                                survey
# 0  Personal and Family Health History
# 1  Personal and Family Health History
# 2  Personal and Family Health History
# 3  Personal and Family Health History
# 4  Personal and Family Health History

# %%
# Show all distinct questions we found, with their question_concept_id
questions_summary = (
    df_q[["question_concept_id", "question"]]
    .drop_duplicates()
    .sort_values("question_concept_id")
)

questions_summary
# Out:
#     question_concept_id  \
# 0                836820
# 8               1384479
# 14              1384540
# 17              1384593
#
#                                                                                               question
# 0     Including yourself, who in your family has had rheumatoid arthritis (RA)? Select all that apply.
# 8                   About how old were you when you were first told you had rheumatoid arthritis (RA)?
# 14  Are you currently prescribed medications and/or receiving treatment for rheumatoid arthritis (RA)?
# 17                Are you still seeing a doctor or health care provider for rheumatoid arthritis (RA)?

# %% [markdown]
# # Inspect answer options for a chosen question
#
# From the table above, choose one `question_concept_id` and list all of its
# answer options. These `answer_concept_id` values are what you will plug into
# `PHENOTYPE_CONFIG['RA']['survey_inclusion_pairs']` or
# `PHENOTYPE_CONFIG['RA']['survey_exclusion_pairs']` in the dataset extraction notebook.

# %%
# ---------------------------------------------------------------
#  Inspect all answer options for a specific question
# ---------------------------------------------------------------

# Example: we are interested in the question:
# "Are you still seeing a doctor or health care provider for rheumatoid arthritis (RA)?"
# From the previous cell, the question_concept_id is 1384593.

target_question_id = 1384593  # <-- change this ID for other questions

df_ra_family = df_q[df_q["question_concept_id"] == target_question_id].copy()

df_ra_family[
    ["question_concept_id", "question", "answer_concept_id", "answer"]
].drop_duplicates()
# Out:
#     question_concept_id  \
# 17              1384593
# 18              1384593
# 19              1384593
#
#                                                                                 question  \
# 17  Are you still seeing a doctor or health care provider for rheumatoid arthritis (RA)?
# 18  Are you still seeing a doctor or health care provider for rheumatoid arthritis (RA)?
# 19  Are you still seeing a doctor or health care provider for rheumatoid arthritis (RA)?
#
#     answer_concept_id  \
# 17             903096
# 18            1384691
# 19            1385113
#
#                                                                                         answer
# 17                                                                                   PMI: Skip
# 18   Are you still seeing a doctor or health care provider for rheumatoid arthritis (RA)? - No
# 19  Are you still seeing a doctor or health care provider for rheumatoid arthritis (RA)? - Yes
